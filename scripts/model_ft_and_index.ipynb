# %%
# !pip install llama-index-vector-stores-faiss
# !pip install llama-index-embeddings-huggingface
# !pip install llama-index
# !pip install faiss-cpu
# !pip install datasets~=2.20.0
# !pip install transformers[torch]
# !pip install accelerate -U

# %% [markdown]
# This notebook was running on a AWS sagemaker ml.g5.4xlarge notebook instance which has one A10 GPU (24G memory)
# To run it you need to install all the dependencies and add your own OpenAI API keys
#
# Dataset can be downloaded from here:

# %%
import datasets
import faiss
import os
import random
from collections import defaultdict
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Document, load_index_from_storage, VectorStoreIndex, StorageContext
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.vector_stores.faiss import FaissVectorStore
from llama_index.core.ingestion import IngestionPipeline

random.seed(42)

# %%
os.environ["OPENAI_API_KEY"] = "Your API Key"

# %%
hotpot_qa = datasets.load_from_disk("data/hotpot_qa_filtered")
wiki_docs = datasets.load_from_disk("data/hotpot_qa_wiki_docs")

# %%
wiki_docs
# Out:
# Dataset({
#     features: ['id', 'url', 'title', 'text'],
#     num_rows: 451380
# })

# %%
hotpot_qa
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context'],
#         num_rows: 76715
#     })
#     validation: Dataset({
#         features: ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context'],
#         num_rows: 6260
#     })
# })

# %%
# hotpot_qa["train"][0]['supporting_facts']

# %%
# hotpot_qa["train"][0]['context']

# %%
def get_pos_sentences(record):
    records = defaultdict(list)
    for title, idx in zip(record['supporting_facts']["title"], record['supporting_facts']["sent_id"]):
        # print(title, idx)
        cont_idx = record['context']["title"].index(title)
        # print(record['context']["title"][cont_idx])
        sentence = record['context']["sentences"][cont_idx][idx]
        # print(sentence)
        records[title].append(sentence)
    return records

def get_pos_chunk(record):
    records = {}
    for title, idx in zip(record['supporting_facts']["title"], record['supporting_facts']["sent_id"]):
        cont_idx = record['context']["title"].index(title)
        records[title] = " ".join(record['context']["sentences"][cont_idx])
    return records

# %% [markdown]
# ### Create training set

# %%
from torch.utils.data import DataLoader
from sentence_transformers import InputExample
from sentence_transformers import losses
from sentence_transformers import SentenceTransformer, SentenceTransformerTrainingArguments, SentenceTransformerTrainer
import random
from datasets import Dataset
from sentence_transformers.evaluation import TripletEvaluator

# %%
def get_triplet_data(record: dict) -> list[InputExample]:
    input_examples = []
    pos_titles = set(record['supporting_facts']["title"])
    pos_chunks = []
    neg_chunks = []
    for title, sentences in zip(record['context']["title"], record['context']["sentences"]):
        if title in pos_titles:
            pos_chunks.append(" ".join(sentences))
        else:
            neg_chunks.append(" ".join(sentences))

    for p_ch in pos_chunks:
        for n_ch in neg_chunks:
            input_examples.append({"anchor": record["question"], "positive": p_ch, "negative":n_ch})
            # input_examples.append([record["question"], p_ch, n_ch])
    return input_examples

# %%
test_examples = []
for record in hotpot_qa["validation"]:
    test_examples.extend(get_triplet_data(record))
    
len(test_examples)
# Out:
# 99526

# %%
test_dataset = Dataset.from_list(random.sample(test_examples, 10000))

# %%
train_examples = []
for record in hotpot_qa["train"]:
    train_examples.extend(get_triplet_data(record))

# %%
len(train_examples)
# Out:
# 1218618

# %%
# set small size for quick iter
TRAIN_SIZE = 100000
EVAL_SIZE = 2000

all_data = random.sample(train_examples, TRAIN_SIZE + EVAL_SIZE)

# %%
train_data = all_data[:TRAIN_SIZE]
len(train_data)
# Out:
# 100000

# %%
eval_data = all_data[TRAIN_SIZE:]
len(eval_data)
# Out:
# 2000

# %%
train_dataset = Dataset.from_list(train_data)

# %%
eval_dataset = Dataset.from_list(eval_data) # change it in final code

# %%
model = SentenceTransformer('Alibaba-NLP/gte-large-en-v1.5', trust_remote_code=True, device="cuda")
triplet_loss = losses.TripletLoss(model=model)
# Out:
# README.md:   0%|          | 0.00/71.8k [00:00<?, ?B/s]

# %%
# (Optional) Get base model performance
test_evaluator = TripletEvaluator(
    anchors=test_dataset["anchor"],
    positives=test_dataset["positive"],
    negatives=test_dataset["negative"],
    batch_size = 16,
    show_progress_bar = True,
    name="hotpot-val-set",
)
test_evaluator(model)
# Out:
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# {'hotpot-val-set_cosine_accuracy': 0.867,
#  'hotpot-val-set_dot_accuracy': 0.1331,
#  'hotpot-val-set_manhattan_accuracy': 0.8678,
#  'hotpot-val-set_euclidean_accuracy': 0.867,
#  'hotpot-val-set_max_accuracy': 0.8678}

# %%
BATCH_SIZE = 4
# LEARNING_RATE = 2e-4
LEARNING_RATE = 1e-5
WARM_RATIO = 0.1

# %%
# 5. (Optional) Specify training arguments
args = SentenceTransformerTrainingArguments(
    # Required parameter:
    output_dir=f"data/ft_models/ft_{TRAIN_SIZE}",
    # Optional training parameters:
    num_train_epochs=1,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE * 2,
    learning_rate=LEARNING_RATE,
    warmup_ratio=WARM_RATIO,
    load_best_model_at_end=True,
    fp16=True,  # Set to False if you get an error that your GPU can't run on FP16
    bf16=False,  # Set to True if you have a GPU that supports BF16
    # batch_sampler=BatchSamplers.NO_DUPLICATES,  # MultipleNegativesRankingLoss benefits from no duplicate samples in a batch
    # Optional tracking/debugging parameters:
    eval_strategy="steps",
    eval_steps=500,
    save_strategy="steps",
    save_steps=500,
    save_total_limit=10,
    logging_steps=500,
    run_name="emb-base-all-triplet-test",  # Will be used in W&B if `wandb` is installed
)

# %%
# 6. (Optional) Create an evaluator & evaluate the base model
dev_evaluator = TripletEvaluator(
    anchors=eval_dataset["anchor"],
    positives=eval_dataset["positive"],
    negatives=eval_dataset["negative"],
    name="hotpot-qa-sample-1k",
)
# dev_evaluator(model)

# %%
# 7. Create a trainer & train
trainer = SentenceTransformerTrainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    loss=triplet_loss,
    evaluator=dev_evaluator,
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='15237' max='25000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15237/25000 1:48:17 < 1:09:23, 2.34 it/s, Epoch 0.61/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Hotpot-qa-sample-1k Cosine Accuracy</th>
#       <th>Hotpot-qa-sample-1k Dot Accuracy</th>
#       <th>Hotpot-qa-sample-1k Manhattan Accuracy</th>
#       <th>Hotpot-qa-sample-1k Euclidean Accuracy</th>
#       <th>Hotpot-qa-sample-1k Max Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.832500</td>
#       <td>1.289250</td>
#       <td>0.916500</td>
#       <td>0.085500</td>
#       <td>0.917500</td>
#       <td>0.917500</td>
#       <td>0.917500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.207500</td>
#       <td>0.870721</td>
#       <td>0.942500</td>
#       <td>0.055000</td>
#       <td>0.943500</td>
#       <td>0.944000</td>
#       <td>0.944000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.018500</td>
#       <td>0.815812</td>
#       <td>0.951500</td>
#       <td>0.050500</td>
#       <td>0.953000</td>
#       <td>0.952000</td>
#       <td>0.953000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.840500</td>
#       <td>0.715509</td>
#       <td>0.957500</td>
#       <td>0.041500</td>
#       <td>0.957500</td>
#       <td>0.958500</td>
#       <td>0.958500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.864500</td>
#       <td>0.734660</td>
#       <td>0.946500</td>
#       <td>0.053500</td>
#       <td>0.955500</td>
#       <td>0.946500</td>
#       <td>0.955500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.851200</td>
#       <td>0.724865</td>
#       <td>0.953500</td>
#       <td>0.046500</td>
#       <td>0.956500</td>
#       <td>0.954000</td>
#       <td>0.956500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.860100</td>
#       <td>0.806895</td>
#       <td>0.950500</td>
#       <td>0.049000</td>
#       <td>0.951500</td>
#       <td>0.951000</td>
#       <td>0.951500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.895500</td>
#       <td>0.763556</td>
#       <td>0.954500</td>
#       <td>0.047000</td>
#       <td>0.953000</td>
#       <td>0.956000</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.821000</td>
#       <td>0.730599</td>
#       <td>0.951500</td>
#       <td>0.049000</td>
#       <td>0.953000</td>
#       <td>0.951500</td>
#       <td>0.953000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.832900</td>
#       <td>0.722934</td>
#       <td>0.954000</td>
#       <td>0.044500</td>
#       <td>0.956500</td>
#       <td>0.954000</td>
#       <td>0.956500</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.783100</td>
#       <td>0.655959</td>
#       <td>0.957000</td>
#       <td>0.044000</td>
#       <td>0.960500</td>
#       <td>0.957000</td>
#       <td>0.960500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.812200</td>
#       <td>0.655593</td>
#       <td>0.951500</td>
#       <td>0.047000</td>
#       <td>0.957500</td>
#       <td>0.951000</td>
#       <td>0.957500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.812200</td>
#       <td>0.674537</td>
#       <td>0.948000</td>
#       <td>0.049500</td>
#       <td>0.952500</td>
#       <td>0.947000</td>
#       <td>0.952500</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.762200</td>
#       <td>0.681620</td>
#       <td>0.956500</td>
#       <td>0.043500</td>
#       <td>0.956500</td>
#       <td>0.956500</td>
#       <td>0.956500</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.788000</td>
#       <td>0.663408</td>
#       <td>0.957500</td>
#       <td>0.042000</td>
#       <td>0.959000</td>
#       <td>0.958000</td>
#       <td>0.959000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.723300</td>
#       <td>0.619974</td>
#       <td>0.955500</td>
#       <td>0.045500</td>
#       <td>0.956000</td>
#       <td>0.955500</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.674000</td>
#       <td>0.586722</td>
#       <td>0.954500</td>
#       <td>0.045500</td>
#       <td>0.954000</td>
#       <td>0.955000</td>
#       <td>0.955000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.742000</td>
#       <td>0.591626</td>
#       <td>0.958000</td>
#       <td>0.041000</td>
#       <td>0.960000</td>
#       <td>0.958500</td>
#       <td>0.960000</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.726700</td>
#       <td>0.581049</td>
#       <td>0.958000</td>
#       <td>0.043000</td>
#       <td>0.960500</td>
#       <td>0.957500</td>
#       <td>0.960500</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.627500</td>
#       <td>0.630143</td>
#       <td>0.955500</td>
#       <td>0.045000</td>
#       <td>0.954500</td>
#       <td>0.955000</td>
#       <td>0.955500</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.736100</td>
#       <td>0.601135</td>
#       <td>0.957500</td>
#       <td>0.041000</td>
#       <td>0.958000</td>
#       <td>0.958000</td>
#       <td>0.958000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.637600</td>
#       <td>0.591707</td>
#       <td>0.958000</td>
#       <td>0.040500</td>
#       <td>0.957000</td>
#       <td>0.956000</td>
#       <td>0.958000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.637900</td>
#       <td>0.569954</td>
#       <td>0.961000</td>
#       <td>0.039000</td>
#       <td>0.962500</td>
#       <td>0.961000</td>
#       <td>0.962500</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.624400</td>
#       <td>0.556234</td>
#       <td>0.961000</td>
#       <td>0.038500</td>
#       <td>0.963000</td>
#       <td>0.961000</td>
#       <td>0.963000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.656000</td>
#       <td>0.580465</td>
#       <td>0.957000</td>
#       <td>0.042000</td>
#       <td>0.960500</td>
#       <td>0.957500</td>
#       <td>0.960500</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.663700</td>
#       <td>0.579506</td>
#       <td>0.961000</td>
#       <td>0.040500</td>
#       <td>0.959500</td>
#       <td>0.961000</td>
#       <td>0.961000</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.652600</td>
#       <td>0.559600</td>
#       <td>0.959500</td>
#       <td>0.041000</td>
#       <td>0.958500</td>
#       <td>0.958000</td>
#       <td>0.959500</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.582800</td>
#       <td>0.537393</td>
#       <td>0.959500</td>
#       <td>0.039500</td>
#       <td>0.958000</td>
#       <td>0.958500</td>
#       <td>0.959500</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.630600</td>
#       <td>0.542299</td>
#       <td>0.959500</td>
#       <td>0.040000</td>
#       <td>0.961500</td>
#       <td>0.958500</td>
#       <td>0.961500</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.629400</td>
#       <td>0.533463</td>
#       <td>0.961500</td>
#       <td>0.037500</td>
#       <td>0.963000</td>
#       <td>0.962500</td>
#       <td>0.963000</td>
#     </tr>
#   </tbody>
# </table><p>
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]

# %%
# help(model.save)

# the result different between Cosine accuracy and dot accuracy means the embedding was not normalized

# https://docs.llamaindex.ai/en/stable/module_guides/models/embeddings/
# Based on the document llama index use cosine similarity by default which works

# %%
trainer.save_model(f"data/ft_models/ft_{TRAIN_SIZE}_v2")

# %%
TRAIN_SIZE
# Out:
# 100000

# %%
# help(SentenceTransformer)
ft_model = SentenceTransformer(f"data/ft_models/ft_{TRAIN_SIZE}_v2", trust_remote_code=True, device="cuda")

# %%
# # (Optional) Evaluate the trained model on the test set
test_evaluator = TripletEvaluator(
    anchors=test_dataset["anchor"],
    positives=test_dataset["positive"],
    negatives=test_dataset["negative"],
    batch_size = 16,
    show_progress_bar = True,
    name="hotpot-val-set",
)
test_evaluator(ft_model)
# Out:
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# {'hotpot-val-set_cosine_accuracy': 0.9619,
#  'hotpot-val-set_dot_accuracy': 0.0386,
#  'hotpot-val-set_manhattan_accuracy': 0.9614,
#  'hotpot-val-set_euclidean_accuracy': 0.9615,
#  'hotpot-val-set_max_accuracy': 0.9619}

# %% [markdown]
# ## Create a baseline using all pretrained model in Val set

# %% [markdown]
# ### Create index For Val set

# %%
# create index for all the 6K validataion queries is very time consuming, select the first 1000 queries for this demo

# %%
all_context_docs = set()

for record in hotpot_qa["validation"].select(range(1000)):
    non_target = set(record["context"]["title"]) - set(record["supporting_facts"]["title"])
    if len(non_target) < 2:
        neg_sample = non_target
    else:
        neg_sample = random.sample(non_target, 2)

    for t in neg_sample:
        all_context_docs.add(t)
    for t in set(record["supporting_facts"]["title"]):
        all_context_docs.add(t)
# Out:
# /tmp/ipykernel_23615/2006841983.py:8: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   neg_sample = random.sample(non_target, 2)

# %%
len(all_context_docs)
# Out:
# 3943

# %%
corpus = wiki_docs.filter(lambda example: example["title"] in all_context_docs)
# Out:
# Filter:   0%|          | 0/451380 [00:00<?, ? examples/s]

# %%
corpus
# Out:
# Dataset({
#     features: ['id', 'url', 'title', 'text'],
#     num_rows: 3752
# })

# %% [markdown]
# ## Create Llama index

# %%
documents = [Document(
    text=doc["text"],
    doc_id=doc["id"],
    metadata={"url":doc["url"], "title": doc["title"]}
) for doc in corpus]

# %% [markdown]
# #### We create index for 3.7K documents in total

# %%
len(documents)
# Out:
# 3752

# %%
# # Only use labeled data

# documents = []

# for record in hotpot_qa["validation"]:
#     for title, sentences in zip(record['context']["title"], record['context']["sentences"]):
#         documents.append(Document(text=" ".join(sentences), metadata={"title": title}))

# %%
# len(documents)

# %%
chuck_splitter = SentenceSplitter(chunk_size=512, chunk_overlap=50)
# nodes = chuck_splitter.get_nodes_from_documents(documents)

embed_model = HuggingFaceEmbedding(model_name=f"data/ft_models/ft_{TRAIN_SIZE}_v2", trust_remote_code=True, embed_batch_size=64,  device='cuda')

# %%
# test the model
test_emeds = embed_model.get_text_embedding("Hello World!")
len(test_emeds)
# Out:
# 1024

# %%
embed_model
# Out:
# HuggingFaceEmbedding(model_name='data/ft_models/ft_100000_v2', embed_batch_size=64, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7f789920d330>, num_workers=None, max_length=8192, normalize=True, query_instruction=None, text_instruction=None, cache_folder=None)

# %%
d = 1024
faiss_index = faiss.IndexFlatL2(d)
vector_store = FaissVectorStore(faiss_index=faiss_index)

# %%
# The following configuration assume one A10 GPU host

# %%
import time

start = time.time()

pipeline = IngestionPipeline(
    transformations=[
        chuck_splitter,
        embed_model,
    ],
)

# Ingest directly into a vector db
# nodes = pipeline.run(nodes=nodes, num_workers=2, show_progress=True)
nodes = pipeline.run(documents=documents, num_workers=2, show_progress=True)

end = time.time()
print(end - start)
# Out:
# WARNING:root:Removing unpickleable private attribute _chunking_tokenizer_fn
# WARNING:root:Removing unpickleable private attribute _split_fns
# WARNING:root:Removing unpickleable private attribute _sub_sentence_split_fns
# WARNING:root:Removing unpickleable private attribute _chunking_tokenizer_fn
# WARNING:root:Removing unpickleable private attribute _split_fns
# WARNING:root:Removing unpickleable private attribute _sub_sentence_split_fns
# 895.2661793231964

# %% [markdown]
# #### For all the 3000 documents we got 22.9K document chunks

# %%
len(nodes)
# Out:
# 22942

# %%
# # store intermediate results
# import pickle

# with open('data/doc_nodes.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(nodes, f)

# %%
# takes about 8 mins to index 500 queries so in total this may take about 2 hours for the whole val set

# %%
storage_context = StorageContext.from_defaults(vector_store=vector_store)
storage_context.docstore.add_documents(nodes)

# %%
index = VectorStoreIndex(
    nodes, storage_context=storage_context, show_progress=True, embed_model=embed_model
)
# Out:
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]

# %% [markdown]
# ### Persist index

# %%
INDEX_STORE = "data/hotpot_qa_storage"

# %%
index.storage_context.persist(persist_dir=INDEX_STORE)

# %% [markdown]
# ## Load index

# %%
# load index from disk
vector_store = FaissVectorStore.from_persist_dir(INDEX_STORE)
storage_context = StorageContext.from_defaults(
    vector_store=vector_store, persist_dir=INDEX_STORE
)
index = load_index_from_storage(storage_context=storage_context, embed_model=embed_model)

# %% [markdown]
# ## Query Index

# %%
# Out:
# Help on method as_retriever in module llama_index.core.indices.vector_store.base:
#
# as_retriever(**kwargs: Any) -> llama_index.core.base.base_retriever.BaseRetriever method of llama_index.core.indices.vector_store.base.VectorStoreIndex instance

# %%
retrieve_engine = index.as_retriever()
response = retrieve_engine.retrieve("What did the author do growing up?")

# %%
response
# Out:
# [NodeWithScore(node=TextNode(id_='fbc13228-b4d6-4a6c-9b2a-c5f484ac10c5', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/C.%20S.%20Lewis', 'title': 'C. S. Lewis'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5813', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/C.%20S.%20Lewis', 'title': 'C. S. Lewis'}, hash='87bcd18afa5a634c294bb2a7c39a01492f368e22b00de2596028d280a9ec48ea'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='9e1f5062-c954-43d3-9fe2-3d9f141496c9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='a4cd2ffbe2904fd62b9967b2f92b40654dc40d2c64c6d33a61d400b4e98a8522')}, text='Clive Staples Lewis  (29 November 1898\xa0– 22 November 1963) was a British writer, literary scholar, and Anglican lay theologian. He held academic positions in English literature at both Magdalen College, Oxford (1925–1954), and Magdalene College, Cambridge (1954–1963). He is best known as the author of The Chronicles of Narnia, but he is also noted for his other works of fiction, such as The Screwtape Letters and The Space Trilogy, and for his non-fiction Christian apologetics, including Mere Christianity, Miracles, and The Problem of Pain.\n\nLewis was a close friend of J.\xa0R.\xa0R. Tolkien, author of The Lord of the Rings. Both men served on the English faculty at Oxford University and were active in the informal Oxford literary group known as the Inklings. According to Lewis\'s 1955 memoir Surprised by Joy, he was baptized in the Church of Ireland but fell away from his faith during adolescence. Lewis returned to Anglicanism at the age of 32, owing to the influence of Tolkien and other friends, and he became an "ordinary layman of the Church of England". Lewis\'s faith profoundly affected his work, and his wartime radio broadcasts on the subject of Christianity brought him wide acclaim.\n\nLewis wrote more than 30 books which have been translated into more than 30 languages and have sold millions of copies. The books that make up The Chronicles of Narnia have sold the most and have been popularized on stage, TV, radio, and cinema. His philosophical writings are widely cited by Christian scholars from many denominations.\n\nIn 1956, Lewis married American writer Joy Davidman; she died of cancer four years later at the age of 45. Lewis died on 22 November 1963 from kidney failure, at age 64. In 2013, on the 50th anniversary of his death, Lewis was honoured with a memorial in Poets\' Corner in Westminster Abbey.\n\nLife\n\nChildhood\n\nClive Staples Lewis was born in Belfast in Ulster, Ireland (before partition), on 29 November 1898.', mimetype='text/plain', start_char_idx=0, end_char_idx=1947, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.9332917332649231),
#  NodeWithScore(node=TextNode(id_='9e488253-f469-448a-8d21-174814d2244f', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/J.%20M.%20Barrie', 'title': 'J. M. Barrie'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='141931', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/J.%20M.%20Barrie', 'title': 'J. M. Barrie'}, hash='0f43b0e78383cc0094c0bfdbeb14d87e4770c32ad34bdffc74c5ece8a6e2c8cf'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='ca65c1d8-7ab5-420a-8e2d-06893080545c', node_type=<ObjectType.TEXT: '1'>, metadata={'url': 'https://en.wikipedia.org/wiki/J.%20M.%20Barrie', 'title': 'J. M. Barrie'}, hash='7ba055ba235b3931e3d4fd57d41ceb29a7124c6d0a87e63e4d47e6e667ea21e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='4d970f23-0bf1-4a59-a954-8c952277564b', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='e5c154542bb5e4fcefdfdafdbe01dcd7bb3c3e16c8f99e34ae97888e4f7c8308')}, text='(161\xa0cm) according to his 1934 passport.\n\nWhen James Barrie was six years old, his elder brother David (their mother\'s favourite) died in an ice-skating accident on the day before his 14th birthday. This left his mother devastated, and Barrie tried to fill David\'s place in his mother\'s attentions, even wearing David\'s clothes and whistling in the manner that he did. One time, Barrie entered her room and heard her say, "Is that you?" "I thought it was the dead boy she was speaking to", wrote Barrie in his biographical account of his mother Margaret Ogilvy (1896) "and I said in a little lonely voice, \'No, it\'s no\' him, it\'s just me. Barrie\'s mother found comfort in the fact that her dead son would remain a boy forever, never to grow up and leave her. Eventually, Barrie and his mother entertained each other with stories of her brief childhood and books such as Robinson Crusoe, works by fellow Scotsman Walter Scott, and The Pilgrim\'s Progress.\n\nAt the age of eight, Barrie was sent to the Glasgow Academy in the care of his eldest siblings, Alexander and Mary Ann, who taught at the school. When he was 10, he returned home and continued his education at the Forfar Academy. At 14, he left home for Dumfries Academy, again under the watch of Alexander and Mary Ann. He became a voracious reader and was fond of penny dreadfuls and the works of Robert Michael Ballantyne and James Fenimore Cooper. At Dumfries, he and his friends spent time in the garden of Moat Brae house, playing pirates "in a sort of Odyssey that was long afterwards to become the play of Peter Pan. They formed a drama club, producing his first play Bandelero the Bandit, which provoked a minor controversy following a scathing moral denunciation from a clergyman on the school\'s governing board.\n\nLiterary career\n\nBarrie knew that he wished to follow a career as an author. However, his family attempted to persuade him to choose a profession such as the ministry. With advice from Alexander, he was able to work out a compromise: he would attend a university but would study literature.', mimetype='text/plain', start_char_idx=1711, end_char_idx=3780, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=1.0747703313827515)]

# %%
query_engine = index.as_query_engine(similarity_top_k=3)
query_engine.query("What did the author do growing up?")
# Out:
# **********
# Trace: query
#     |_query -> 0.962059 seconds
#       |_synthesize -> 0.933216 seconds
#         |_templating -> 1.6e-05 seconds
#         |_llm -> 0.927075 seconds
# **********
# Response(response='The author attended the Glasgow Academy at the age of eight, then continued his education at the Forfar Academy at the age of 10. Later, at 14, he left home for Dumfries Academy, where he became a voracious reader and enjoyed penny dreadfuls and the works of various authors.', source_nodes=[NodeWithScore(node=TextNode(id_='fbc13228-b4d6-4a6c-9b2a-c5f484ac10c5', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/C.%20S.%20Lewis', 'title': 'C. S. Lewis'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5813', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/C.%20S.%20Lewis', 'title': 'C. S. Lewis'}, hash='87bcd18afa5a634c294bb2a7c39a01492f368e22b00de2596028d280a9ec48ea'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='9e1f5062-c954-43d3-9fe2-3d9f141496c9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='a4cd2ffbe2904fd62b9967b2f92b40654dc40d2c64c6d33a61d400b4e98a8522')}, text='Clive Staples Lewis  (29 November 1898\xa0– 22 November 1963) was a British writer, literary scholar, and Anglican lay theologian. He held academic positions in English literature at both Magdalen College, Oxford (1925–1954), and Magdalene College, Cambridge (1954–1963). He is best known as the author of The Chronicles of Narnia, but he is also noted for his other works of fiction, such as The Screwtape Letters and The Space Trilogy, and for his non-fiction Christian apologetics, including Mere Christianity, Miracles, and The Problem of Pain.\n\nLewis was a close friend of J.\xa0R.\xa0R. Tolkien, author of The Lord of the Rings. Both men served on the English faculty at Oxford University and were active in the informal Oxford literary group known as the Inklings. According to Lewis\'s 1955 memoir Surprised by Joy, he was baptized in the Church of Ireland but fell away from his faith during adolescence. Lewis returned to Anglicanism at the age of 32, owing to the influence of Tolkien and other friends, and he became an "ordinary layman of the Church of England". Lewis\'s faith profoundly affected his work, and his wartime radio broadcasts on the subject of Christianity brought him wide acclaim.\n\nLewis wrote more than 30 books which have been translated into more than 30 languages and have sold millions of copies. The books that make up The Chronicles of Narnia have sold the most and have been popularized on stage, TV, radio, and cinema. His philosophical writings are widely cited by Christian scholars from many denominations.\n\nIn 1956, Lewis married American writer Joy Davidman; she died of cancer four years later at the age of 45. Lewis died on 22 November 1963 from kidney failure, at age 64. In 2013, on the 50th anniversary of his death, Lewis was honoured with a memorial in Poets\' Corner in Westminster Abbey.\n\nLife\n\nChildhood\n\nClive Staples Lewis was born in Belfast in Ulster, Ireland (before partition), on 29 November 1898.', mimetype='text/plain', start_char_idx=0, end_char_idx=1947, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.9332917332649231), NodeWithScore(node=TextNode(id_='9e488253-f469-448a-8d21-174814d2244f', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/J.%20M.%20Barrie', 'title': 'J. M. Barrie'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='141931', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/J.%20M.%20Barrie', 'title': 'J. M. Barrie'}, hash='0f43b0e78383cc0094c0bfdbeb14d87e4770c32ad34bdffc74c5ece8a6e2c8cf'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='ca65c1d8-7ab5-420a-8e2d-06893080545c', node_type=<ObjectType.TEXT: '1'>, metadata={'url': 'https://en.wikipedia.org/wiki/J.%20M.%20Barrie', 'title': 'J. M. Barrie'}, hash='7ba055ba235b ...

# %%
# help(Settings)

# %%
from llama_index.core.callbacks import CallbackManager, LlamaDebugHandler
from llama_index.core import Settings
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine
from llama_index.core.base.base_query_engine import BaseQueryEngine
import nest_asyncio
from llama_index.llms.openai import OpenAI
import json
import os
import string
from openai import AsyncOpenAI

nest_asyncio.apply()
client = AsyncOpenAI()

# %%
# help(QueryEngineTool)

# %%
# Using the LlamaDebugHandler to print the trace of the sub questions
# captured by the SUB_QUESTION callback event type
query_engine = index.as_query_engine(similarity_top_k=3)
llama_debug = LlamaDebugHandler(print_trace_on_end=True)
callback_manager = CallbackManager([llama_debug])

Settings.callback_manager = callback_manager

# %%
# help(CallbackManager)

# %%
# setup base query engine as tool
query_engine_tools = [
    QueryEngineTool(
        query_engine=query_engine,
        metadata=ToolMetadata(
            name="wiki_search_engine",
            description="Wikipedia query engin",
        ),
    ),
]
# llm = OpenAI(temperature=0.1, model="gpt-4o")

sub_query_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=query_engine_tools,
    use_async=True,
    llm=llm,
)

# %%
help(SubQuestionQueryEngine.from_defaults)
# Out:
# Help on method from_defaults in module llama_index.core.query_engine.sub_question_query_engine:
#
# from_defaults(query_engine_tools: Sequence[llama_index.core.tools.query_engine.QueryEngineTool], llm: Optional[llama_index.core.llms.llm.LLM] = None, question_gen: Optional[llama_index.core.question_gen.types.BaseQuestionGenerator] = None, response_synthesizer: Optional[llama_index.core.response_synthesizers.base.BaseSynthesizer] = None, service_context: Optional[llama_index.core.service_context.ServiceContext] = None, verbose: bool = True, use_async: bool = True) -> 'SubQuestionQueryEngine' method of abc.ABCMeta instance

# %%
# help(query_engine)

# %%
query_engine.query(
    "Were Scott Derrickson and Ed Wood of the same nationality?"
)
# Out:
# **********
# Trace: query
#     |_query -> 0.50256 seconds
#       |_synthesize -> 0.474832 seconds
#         |_templating -> 1.5e-05 seconds
#         |_llm -> 0.470094 seconds
# **********
# Response(response='Yes.', source_nodes=[NodeWithScore(node=TextNode(id_='7bd3e25a-5261-4ebd-a7c1-1d85e04c01d8', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/Scott%20Derrickson', 'title': 'Scott Derrickson'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2816539', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/Scott%20Derrickson', 'title': 'Scott Derrickson'}, hash='031edde4c8df5319ef6dc8f2e3a4bb0f38b84a0cca7fbaa670fa156d5390ee81'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='8b1c9c7f-339f-4258-9de6-4f77868fbf48', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='733ed73c5e27905b06f56b5f8ce7bc576f22a061cb03c6e77b992f148af447a9')}, text='Scott Derrickson (born July 16, 1966) is an American filmmaker. He is best known for his work in the horror genre, directing films such as The Exorcism of Emily Rose (2005), Sinister (2012) and The Black Phone (2021). He is also known for the superhero film Doctor Strange (2016), based on the Marvel Comics character.\n\nEarly life\nScott Derrickson grew up in Denver, Colorado. He graduated from Biola University with a B.A. in Humanities with an emphasis in philosophy and literature and a B.A. in communications with an emphasis in film and a minor in theology. He completed his graduate studies at USC School of Cinema-Television.\n\nCareer \nDerrickson\'s debut feature was Hellraiser: Inferno, the fifth installment in the long-running Hellraiser film series. It was released straight to video in 2000. Following this, Derrickson and co-writer Paul Harris Boardman spent several years doing script-doctoring work for studios. "I was paid to write or rewrite 13 screenplays," Derrickson said, "None of them got made. I was earning a good living but all of my creativity would be read by just a handful of executives. It caused a kind of soul sickness in me." In 2004, he conceived the story for Land of Plenty for German director Wim Wenders.\n\nDerrickson co-wrote and directed The Exorcism of Emily Rose, which was loosely based on a true story about Anneliese Michel. The film won the 2005 Saturn Award for Best Horror or Thriller Film and in 2006 was named in the Chicago Film Critics Association\'s list of the "Top 100 Scariest Films Ever Made." Theatrical box office gross for The Exorcism of Emily Rose was over $144 million worldwide. It received the award for Best Horror Film at the 32nd Saturn Awards.\n\nDerrickson next directed a remake of The Day the Earth Stood Still, starring Keanu Reeves and Jennifer Connelly, written by David Scarpa. The film was released in late 2008 and earned over $233 million worldwide.', mimetype='text/plain', start_char_idx=0, end_char_idx=1923, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.6371361017227173), NodeWithScore(node=TextNode(id_='8987c79a-9c32-427d-aff8-497f86739a0d', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/Ed%20Wood', 'title': 'Ed Wood'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='10520', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/Ed%20Wood', 'title': 'Ed Wood'}, hash='d91797d43ef6c39eafb49579e70efeb4c76be630ebd6e7a29437829b1810a65d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='284b3464-a300-4b97-8fba-ecb6e35b25d2', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='70ed410e10c78a819f6fd6c437f561c1e310e4319c599dce31913e6687d0c4f9')}, text="Edward Davis Wood Jr. (October 10, 1924\xa0– December 10, 1978) was an American filmmaker, actor, and pulp novelist.\n\nIn the 1950s, Wood directed several low-budget science fiction, crime and horror films that later became cult classics, notably Glen or Glenda (1953), Jail Bait (1954), Bride of the Monster (1955), Plan 9 from Oute ...

# %%
sub_query_engine.query(
    "What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?"
)
# Out:
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who portrayed Corliss Archer in the film Kiss and Tell?
# [wiki_search_engine] Q: What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
# [wiki_search_engine] A: Chief of Protocol of the United States
# [wiki_search_engine] A: Shirley Temple
# **********
# Trace: query
#     |_query -> 1.903579 seconds
#       |_llm -> 1.051759 seconds
#       |_sub_question -> 0.541399 seconds
#         |_query -> 0.541021 seconds
#           |_synthesize -> 0.51277 seconds
#             |_templating -> 1.7e-05 seconds
#             |_llm -> 0.507151 seconds
#       |_sub_question -> 0.464494 seconds
#         |_query -> 0.464119 seconds
#           |_synthesize -> 0.436556 seconds
#             |_templating -> 1.5e-05 seconds
#             |_llm -> 0.431738 seconds
#       |_synthesize -> 0.308534 seconds
#         |_templating -> 1.6e-05 seconds
#         |_llm -> 0.306352 seconds
# **********
# Response(response='Chief of Protocol of the United States', source_nodes=[NodeWithScore(node=TextNode(id_='57133d82-e021-470f-b574-42331caeab39', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Sub question: Who portrayed Corliss Archer in the film Kiss and Tell?\nResponse: Shirley Temple', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=None), NodeWithScore(node=TextNode(id_='5594265b-ca62-46f0-9aff-93ccaae37d11', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Sub question: What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?\nResponse: Chief of Protocol of the United States', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=None), NodeWithScore(node=TextNode(id_='c9ea54e5-8848-46a2-9f1c-acc79e88d070', embedding=None, metadata={'url': 'https://en.wikipedia.org/wiki/Kiss%20and%20Tell%20%281945%20film%29', 'title': 'Kiss and Tell (1945 film)'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='33022480', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'url': 'https://en.wikipedia.org/wiki/Kiss%20and%20Tell%20%281945%20film%29', 'title': 'Kiss and Tell (1945 film)'}, hash='6d91bfdc003111774cdc067ce20bbf6b67070eb5d575d6e989e9ba4dd5a8891d'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='3151c4dc-4bc5-4508-a948-708972de2c80', node_type=<ObjectType.TEXT: '1'>, metadata={'url': 'https://en.wikipedia.org/wiki/Kiss%20and%20Tell%20%281945%20film%29', 'title': 'Kiss and Tell (1945 film)'}, hash='76eea1665d3c7d362d6329c67265493dc72aeae0b3ac934863b3583d09657f2b'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='5c81b371-902a-4b06-b234-15696b2adcfd', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='46cba271d70b2235d17d2c3cd1afd1b85f32bf81501d794520dd1fdbc7264af7')}, text='Lenny only tells his sister Corliss of what they have done, and makes her swear not to tell anyone. The feud gets worse when Mr. Pringle and Mr. Archer start a fist fight and punch each other in the face. The injuries from the fight result in lawsuits from both families against each other. The feud drags on for months.\n\nEventually Mildred finds out that she is pregnant, and she goes to see an obstetrician. Corliss goes with her, and is spotted by Mrs. Wilcox, the town gossip. Corliss is seen talking to Jimmy on the street, directly after leaving the doctor\'s office, and Mrs. Wilcox instantly and eagerly passes the information on to Mrs. Pringle.\n\nMrs. Pringle sees her chance to get back at the Archers, so she confronts them with the claim that Corliss is pregnant and that Jimmy is the father. Corliss doesn\'t want Mildred and her brother to get into trouble, so she admits to being pregnant. When Mrs. Archer tries to call Jimmy\'s superior officer to scold him, Corliss says Dexter is the father. Then she intercepts her mother by telling Dexter what she has said, asking him to help her out by lying.\n\nCorliss tries to soften the blow for her parents by lying again, telling them that she and Dexter are already married. Mr. Archer doesn\'t believe her, so she tells him they were married across the state line. When Mr. Archer calls the justice who performed the ceremony, the man confirms that an Archer was married there months ago. Soon the Franklins are informed of their son\'s endeavours, and both families gather at Archer\'s house. Uncle George Archer, who is a Navy chaplain, insists on performing another, "proper" wedding ceremony for the young couple.\n\nThe same night, Mildred hears news that Lenny has performed heroically ...

# %% [markdown]
# ### Quick QA eval
#
# We need a way to eval whether the answer is correct. To do that we do two things: 1. If the model generated answer contain the ground truth answer then mark it correct. 2. If the model generated answer doesn't contain the exact ground truth answer then use a LLM to decide wether the answer is correct or not.

# %%
# disable logs
Settings.callback_manager = None

# %%
# sub_query_engine.query(
#     "What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?"
# )

# %%
test_qa = hotpot_qa["validation"].select(range(1000))

# %%
test_qa[0].keys()
# Out:
# dict_keys(['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context'])

# %%
def get_answer(example: dict, query_engine: BaseQueryEngine=sub_query_engine) -> dict:
    resp = query_engine.query(example["question"])
    return {"ft_gen_ans": resp.response}

# %%
get_answer(test_qa[0])
# Out:
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the nationality of Scott Derrickson?
# [wiki_search_engine] Q: What is the nationality of Ed Wood?
# [wiki_search_engine] A: American
# [wiki_search_engine] A: The nationality of Ed Wood is American.
# {'ft_gen_ans': 'Yes, Scott Derrickson and Ed Wood were of the same nationality.'}

# %%
# huggingface emb model doesn't support concurrent execution, need to figure out a way to setup different model worker so we can use num_proc > 1
test_qa = test_qa.map(get_answer, num_proc=1)
# Out:
# WARNING:root:Removing unpickleable private attribute _client
# WARNING:root:Removing unpickleable private attribute _aclient
# WARNING:root:Removing unpickleable private attribute _model
# WARNING:root:Removing unpickleable private attribute _chunking_tokenizer_fn
# WARNING:root:Removing unpickleable private attribute _split_fns
# WARNING:root:Removing unpickleable private attribute _sub_sentence_split_fns
# WARNING:root:Removing unpickleable private attribute _client
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the nationality of Scott Derrickson?
# [wiki_search_engine] Q: What is the nationality of Ed Wood?
# [wiki_search_engine] A: American
# [wiki_search_engine] A: The nationality of Ed Wood is American.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who portrayed Corliss Archer in the film Kiss and Tell?
# [wiki_search_engine] Q: What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
# [wiki_search_engine] A: Shirley Temple portrayed Corliss Archer in the film Kiss and Tell.
# [wiki_search_engine] A: The woman who portrayed Corliss Archer in the film Kiss and Tell held the position of United States Ambassador to Czechoslovakia.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the location of the Laleli Mosque?
# [wiki_search_engine] Q: What is the location of the Esma Sultan Mansion?
# [wiki_search_engine] A: The Esma Sultan Mansion is located in the Ortaköy neighborhood of Istanbul, Turkey, along the Bosphorus.
# [wiki_search_engine] A: The Laleli Mosque is located in Laleli, Fatih, Istanbul, Turkey.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who is the director of the romantic comedy 'Big Stone Gap'?
# [wiki_search_engine] Q: In which New York city is the director of 'Big Stone Gap' based?
# [wiki_search_engine] A: Doug Liman
# [wiki_search_engine] A: New York City.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the name of the South Korean boy group that released the debut album 2014 S/S?
# [wiki_search_engine] Q: Who formed the South Korean boy group that released the debut album 2014 S/S?
# [wiki_search_engine] A: Winner
# [wiki_search_engine] A: YG Entertainment formed the South Korean boy group Winner, which released their debut album 2014 S/S.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the birthdate of Annie Morton?
# [wiki_search_engine] Q: What is the birthdate of Terry Richardson?
# [wiki_search_engine] A: Annie Morton was born on October 8, 1970.
# [wiki_search_engine] A: August 14, 1965
# Generated 2 sub questions.
# [wiki_search_engine] Q: Where is the band Local H from?
# [wiki_search_engine] Q: Where is the band For Against from?
# [wiki_search_engine] A: Local H is from Zion, Illinois.
# [wiki_search_engine] A: For Against is from Lincoln, Nebraska, United States.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the name of the university whose main campus is in Lawrence, Kansas and whose branch campuses are in the Kansas City metropolitan area?
# [wiki_search_engine] Q: What is the fight song of the university whose main campus is in Lawrence, Kansas?
# [wiki_search_engine] A: The fight song of the university whose main campus is in Lawrence, Kansas is "Crimson and the Blue".
# [wiki_search_engine] A: The name of the university whose main campus is in Lawrence, Kansas and whose branch campuses are in the Kansas City metropolitan area is the University of Kansas (KU).
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who are the screenwriters credited for the film 'Evolution'?
# [wiki_search_engine] Q: Which films starring Nicolas Cage and Téa Leoni have been co-written by any of the screenwriters of 'Evolution'?
# [wiki_search_engine] A: Dan Harris and David Diamond are the screenwriters credited for the film 'Evolution'.
# [wiki_search_engine] A: The films starring Nicolas Cage and Téa Leoni that have been co-written by any of the screenwriters of 'Evolution' are 'The Family Man'.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What year did Guns N' Roses perform a promo for a movie starring Arnold Schwarzenegger as a former New York Police detective?
# [wiki_search_engine] Q: Which movie starring Arnold Schwarzenegger as a former New York Police detective had a promo performed by Guns N' Roses?
# [wiki_search_engine] A: The movie starring Arnold Schwarzenegger as a former New York Police detective that had a promo performed by Guns N' Roses is "Last Action Hero."
# [wiki_search_engine] A: Guns N' Roses performed a promo for a movie starring Arnold Schwarzenegger as a former New York Police detective in 1991.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who recruited David Beckham as a football player?
# [wiki_search_engine] Q: Who was the manager of Manchester United when David Beckham was recruited?
# [wiki_search_engine] Q: What was the timeframe during which the manager who recruited David Beckham managed Manchester United?
# [wiki_search_engine] A: Alex Ferguson
# [wiki_search_engine] A: Ferguson recruited David Beckham as a football player.
# [wiki_search_engine] A: The manager who recruited David Beckham managed Manchester United from November 1986 to May 2013.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What country is Brown State Fishing Lake located in?
# [wiki_search_engine] Q: What is the population of the country where Brown State Fishing Lake is located?
# [wiki_search_engine] A: The population of the country where Brown State Fishing Lake is located exceeds 334 million.
# [wiki_search_engine] A: The Brown State Fishing Lake is located in the United States.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What conference does the Vermont Catamounts men's soccer team currently compete in?
# [wiki_search_engine] Q: What was the name of the conference that the Vermont Catamounts men's soccer team competed in from 1988 to 1996?
# [wiki_search_engine] A: ECAC Hockey
# [wiki_search_engine] A: The Vermont Catamounts men's soccer team currently competes in the America East Conference.
# Generated 6 sub questions.
# [wiki_search_engine] Q: Who is Giuseppe Verdi?
# [wiki_search_engine] Q: Who is Ambroise Thomas?
# [wiki_search_engine] Q: What are the notable works of Giuseppe Verdi?
# [wiki_search_engine] Q: What are the notable works of Ambroise Thomas?
# [wiki_search_engine] Q: Did Giuseppe Verdi compose operas?
# [wiki_search_engine] Q: Did Ambroise Thomas compose operas?
# [wiki_search_engine] A: Giuseppe Verdi composed operas.
# [wiki_search_engine] A: Ambroise Thomas composed operas, including notable works such as "Mignon" (1866) and "Hamlet" (1868).
# [wiki_search_engine] A: Notable works of Ambroise Thomas include "Mignon", "Hamlet", "Françoise de Rimini", "Le caïd", "Le songe d'une nuit d'été", and "Raymond".
# [wiki_search_engine] A: The notable works of Giuseppe Verdi include "Rigoletto," "Il trovatore," "La traviata," "Otello," and "Falstaff."
# [wiki_search_engine] A: Ambroise Thomas was a French composer and teacher known for his operas Mignon and Hamlet. He was born into a musical family and studied at the Conservatoire de Paris, winning the Prix de Rome. Thomas composed a total of twenty operas, both comic and serious, finding success in France and abroad. He also served as a professor at the Conservatoire and later became its director. Despite being known for his conservative musical views, his operas have experienced a revival in recent decades.
# [wiki_search_engine] A: Giuseppe Verdi was an Italian composer best known for his operas. He was born in 1813 to a provincial family and received a musical education with the help of a local patron. Verdi became a dominant figure in Italian opera after the era of Rossini, Bellini, and Donizetti. He demonstrated sympathy with the Risorgimento movement and his works, such as the chorus "Va, pensiero" from Nabucco, reflected the spirit of the unification movement. Verdi's operas, including Rigoletto, Il trovatore, and La traviata, remain popular today. He passed away in 1901 at the age of 87.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who was Roger O. Egeberg?
# [wiki_search_engine] Q: Which president's administration did Roger O. Egeberg serve as Assistant Secretary for Health and Scientific Affairs?
# [wiki_search_engine] Q: What were the years of the administration during which Roger O. Egeberg served as Assistant Secretary for Health and Scientific Affairs?
# [wiki_search_engine] A: Nixon
# [wiki_search_engine] A: Roger O. Egeberg served as Assistant Secretary for Health and Scientific Affairs from 1969 to 1971.
# [wiki_search_engine] A: Roger O. Egeberg was an American medical educator, administrator, and advocate of public health. He served as General Douglas MacArthur's personal physician during World War II and held various academic positions, including being the Dean of the University of Southern California's medical school. Egeberg also worked in the Nixon administration as the Assistant Secretary for Health and Scientific Affairs in the Department of Health, Education, and Welfare. Additionally, he played a role in changing the penalties for marijuana offenses and provided advice on how marijuana should be regulated.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who are the Mexican Formula One race car drivers who have held the podium?
# [wiki_search_engine] Q: Which Mexican Formula One race car driver was born in 1990 and drove for Force India?
# [wiki_search_engine] A: Sergio Pérez
# [wiki_search_engine] A: Pedro Rodríguez, Sergio Pérez, and Esteban Gutiérrez are the Mexican Formula One race car drivers who have held the podium.
# Generated 3 sub questions.
# [wiki_search_engine] Q: What is the Apple Remote?
# [wiki_search_engine] Q: What program was the Apple Remote originally designed to interact with?
# [wiki_search_engine] Q: What other devices can control the program that the Apple Remote was originally designed to interact with?
# [wiki_search_engine] A: The Apple Remote was originally designed to interact with the Front Row media center program on the iMac G5.
# [wiki_search_engine] A: The Siri Remote, which was introduced with the 4th Generation Apple TV in 2015, can also control the program that the Apple Remote was originally designed to interact with.
# [wiki_search_engine] A: The Apple Remote is a remote control device introduced by Apple Inc. in October 2005 for use with various products that have infrared capability. It was initially designed to control the Front Row media center program on the iMac G5 and is compatible with many subsequent Macintosh computers. The remote has undergone design changes over the years, with the original version made of white plastic and later versions featuring an aluminum design. It has been used for functions such as navigating media, controlling presentations, adjusting volume, and interacting with various software applications on Apple devices.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the list of band members and the instruments they play for Badly Drawn Boy?
# [wiki_search_engine] Q: What is the list of band members and the instruments they play for Wolf Alice?
# [wiki_search_engine] A: Damon Michael Gough is the sole member of Badly Drawn Boy, serving as the indie singer-songwriter and multi-instrumentalist for the band.
# [wiki_search_engine] A: Ellie Rowsell plays lead vocals, guitar, keyboards, synthesizers, and piano. Joff Oddie plays guitar, violin, and synthesizers. Theo Ellis plays bass guitar and synthesizers. Joel Amey plays drums, percussion, synthesizers, and backing vocals. Ryan Malcolm plays keyboards, synthesizers, piano, percussion, and backing vocals as a current touring musician.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who is the father of Kasper Schmeichel?
# [wiki_search_engine] Q: What awards or titles did the father of Kasper Schmeichel receive in 1992?
# [wiki_search_engine] Q: What is the IFFHS and what awards do they give?
# [wiki_search_engine] A: Peter Schmeichel
# [wiki_search_engine] A: He was named as one of the "125 greatest living footballers" at the FIFA 100 celebrations in 2004.
# [wiki_search_engine] A: The IFFHS is the International Federation of Football History & Statistics. They give out awards for the World's Best Goalkeeper annually, ranking the top goalkeepers based on their performances throughout the year.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who was the writer of 'These Boots Are Made for Walkin'?
# [wiki_search_engine] Q: Who died in 2007?
# [wiki_search_engine] A: Lee Hazlewood
# [wiki_search_engine] A: No one mentioned in the provided context information died in 2007.
# Generated 4 sub questions.
# [wiki_search_engine] Q: In what year was Virginia Commonwealth University founded?
# [wiki_search_engine] Q: Who was the head coach of the 2011–12 VCU Rams men's basketball team?
# [wiki_search_engine] Q: What was the performance of the 2011–12 VCU Rams men's basketball team?
# [wiki_search_engine] Q: What is the history of Virginia Commonwealth University?
# [wiki_search_engine] A: Anthony Grant
# [wiki_search_engine] A: Virginia Commonwealth University was founded in 1838.
# [wiki_search_engine] A: Virginia Commonwealth University was established in 1968 through the merger of the Medical College of Virginia and the Richmond Professional Institute. It has since grown to become a prominent public research university located in Richmond, Virginia.
# [wiki_search_engine] A: The 2011–12 VCU Rams men's basketball team had a successful season, highlighted by an eleven-game winning streak that improved their overall record to 22–5 and their conference record to 13–2. They were unofficially ranked 36th in the nation amongst Division I schools and reached the CAA Championship, where they won their fifth CAA tournament by defeating Drexel 59–56.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Is Dictyosperma described as a genus?
# [wiki_search_engine] Q: Is Huernia described as a genus?
# [wiki_search_engine] A: Huernia is described as a genus.
# [wiki_search_engine] A: Yes.
# Generated 1 sub questions.
# [wiki_search_engine] Q: Where is the band Buck-Tick from?
# [wiki_search_engine] A: Buck-Tick is from Fujioka, Gunma, Japan.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who was the French ace pilot that flew L'Oiseau Blanc?
# [wiki_search_engine] Q: Who was the French adventurer that flew L'Oiseau Blanc?
# [wiki_search_engine] Q: What is L'Oiseau Blanc?
# [wiki_search_engine] Q: What was the significance of L'Oiseau Blanc in aviation history?
# [wiki_search_engine] A: Charles Nungesser.
# [wiki_search_engine] A: Charles Nungesser was the French ace pilot who flew L'Oiseau Blanc.
# [wiki_search_engine] A: L'Oiseau Blanc is a French Levasseur PL.8 biplane that disappeared in 1927 during an attempt to make the first non-stop transatlantic flight between Paris and New York City to compete for the Orteig Prize.
# [wiki_search_engine] A: L'Oiseau Blanc holds significance in aviation history due to its attempt to make the first non-stop transatlantic flight between Paris and New York City in 1927. The disappearance of the aircraft and its crew, Charles Nungesser and François Coli, during this attempt became one of the great mysteries in aviation history. The event garnered international attention and influenced subsequent aviation achievements, such as Charles Lindbergh's successful non-stop flight shortly after, which had a major impact on the American aviation industry. Monuments, museums, and commemorative stamps were dedicated to honor Nungesser and Coli's attempt, highlighting the lasting legacy of L'Oiseau Blanc in aviation history.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the country of origin for the documentary 'Freakonomics'?
# [wiki_search_engine] Q: What is the country of origin for the documentary 'In the Realm of the Hackers'?
# [wiki_search_engine] A: Australia
# [wiki_search_engine] A: The country of origin for the documentary 'Freakonomics' is the United States.
# Generated 2 sub questions.
# [wiki_search_engine] Q: How many members did the band Letters to Cleo have?
# [wiki_search_engine] Q: How many members did the band Screaming Trees have?
# [wiki_search_engine] A: Screaming Trees had four members in the band.
# [wiki_search_engine] A: Letters to Cleo had six members.
# Generated 5 sub questions.
# [wiki_search_engine] Q: Who was Alexander Kerensky?
# [wiki_search_engine] Q: What was the role of Alexander Kerensky in the Russian Civil War?
# [wiki_search_engine] Q: Who were the Bolsheviks?
# [wiki_search_engine] Q: What were the key events leading to the defeat of Alexander Kerensky by the Bolsheviks?
# [wiki_search_engine] Q: When did the Russian Civil War end?
# [wiki_search_engine] A: Alexander Kerensky was not mentioned in the provided context information.
# [wiki_search_engine] A: The Russian Civil War ended in 1922.
# [wiki_search_engine] A: The Bolsheviks were a faction led by Vladimir Lenin that emerged as a prominent group during the Russian Civil War. They were known for their socialist and revolutionary ideologies and played a significant role in the events that unfolded during the conflict.
# [wiki_search_engine] A: The Cossacks were repulsed in the Pulkovo Heights, leading to their retreat from Tsarskoye Selo back to Gatchina. Kerensky's forces began to disperse and some even fraternized with the Bolsheviks. Kerensky's morale was weakened due to lack of support, and he was in danger of being arrested by his own men. Eventually, he was forced to flee in disguise as a sailor. This escape marked the end of hopes to restore the Provisional Government, and the defeat of Kerensky allowed Lenin and the Bolsheviks to secure their power.
# [wiki_search_engine] A: Alexander Kerensky played a significant role in the Russian Civil War as a key figure in the Provisional Government that was established after the February Revolution of 1917. He served as the Prime Minister of the Provisional Government and later became the leader of the Russian political party known as the Socialist Revolutionary Party. Kerensky's leadership during this turbulent period marked a transitional phase between the fall of the Tsarist regime and the rise of the Bolsheviks, influencing the course of events that led to the Civil War.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who is the author of 'Seven Brief Lessons on Physics'?
# [wiki_search_engine] Q: In which year did the author of 'Seven Brief Lessons on Physics' start working in France?
# [wiki_search_engine] A: Carlo Rovelli
# [wiki_search_engine] A: In 2021, the author of 'Seven Brief Lessons on Physics' started working in France.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the Livesey Hal War Memorial?
# [wiki_search_engine] Q: Which war had over 60 million casualties?
# [wiki_search_engine] A: The Korean War had over 60 million casualties.
# [wiki_search_engine] A: The Livesey Hall War Memorial is a Grade II listed building located in England. It was designed and sculpted by the British artist Sydney March, who was known for his work on war memorials and sculptures of British royalty and other contemporary figures.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Where is Elko Regional Airport located?
# [wiki_search_engine] Q: Where is Gerald R. Ford International Airport located?
# [wiki_search_engine] A: Elko Regional Airport is located a mile west of downtown Elko, in Elko County, Nevada, United States.
# [wiki_search_engine] A: Gerald R. Ford International Airport is located at the intersection of 44th Street and Patterson Avenue. It abuts I-96 on the east, M-6 on the south, M-37 on the west, and M-11 on the north.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who was Ralph Hefferline?
# [wiki_search_engine] Q: Which university did Ralph Hefferline work at?
# [wiki_search_engine] Q: In which city is the university where Ralph Hefferline worked located?
# [wiki_search_engine] A: Columbia University
# [wiki_search_engine] A: New York
# [wiki_search_engine] A: Ralph Hefferline was a psychology professor at Columbia University who later became a patient of Fritz Perls and contributed to the book that defined Gestalt Therapy. He joined the Behaviourist school of psychology and co-authored a chapter in the book "Gestalt Therapy, Excitement and Growth in the Human Personality" with Fritz Perls and Paul Goodman.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What company did Sachin Warrier work for as a software engineer?
# [wiki_search_engine] Q: Where is the headquarters of the company that Sachin Warrier worked for as a software engineer?
# [wiki_search_engine] A: Tata Consultancy Services
# [wiki_search_engine] A: Kochi
# Generated 4 sub questions.
# [wiki_search_engine] Q: What was the battle in which Giuseppe Arimondi lost his life?
# [wiki_search_engine] Q: What was the significance of the battle in which Giuseppe Arimondi lost his life for Ethiopia?
# [wiki_search_engine] Q: What were the outcomes of the battle in which Giuseppe Arimondi lost his life?
# [wiki_search_engine] Q: Who was Giuseppe Arimondi and what was his role in the battle?
# [wiki_search_engine] A: Adwa
# [wiki_search_engine] A: The battle in which Giuseppe Arimondi lost his life was a fundamental turning point in Ethiopian history.
# [wiki_search_engine] A: Giuseppe Arimondi lost his life in combat at Adwa and was posthumously awarded the Gold Medal of Military Valour.
# [wiki_search_engine] A: Giuseppe Arimondi was an Italian general known for his role during the First Italo-Ethiopian War. In the battle, he soundly defeated the Mahdists at Agordat in 1893 by deploying his men in an extended battle line, catching the Mahdists by surprise.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who was Alfred Balk?
# [wiki_search_engine] Q: What was the Committee on the Employment of Minority Groups in the News Media?
# [wiki_search_engine] Q: Who were the United States Vice Presidents during Alfred Balk's career?
# [wiki_search_engine] Q: Under which United States Vice President did Alfred Balk serve as the secretary of the Committee on the Employment of Minority Groups in the News Media?
# [wiki_search_engine] A: Spiro Agnew and Hubert Humphrey were the United States Vice Presidents during Alfred Balk's career.
# [wiki_search_engine] A: Alfred Balk served as the secretary of the Committee on the Employment of Minority Groups in the News Media under New York Governor Nelson Rockefeller.
# [wiki_search_engine] A: The Committee on the Employment of Minority Groups in the News Media was a group that aimed to address issues related to diversity and representation of minority groups in the news media industry.
# [wiki_search_engine] A: Alfred Balk was a prominent writer and journalist known for his investigative reporting on a variety of social issues and events. He wrote for publications such as the Saturday Evening Post, Harper's, Reader's Digest, The Reporter, and The New York Times Magazine, covering topics ranging from real estate practices to public parkland threats. He also co-authored a report on the rise of Elijah Muhammad's Nation of Islam with Alex Haley.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the first track on the box set Back to Mono?
# [wiki_search_engine] Q: Who is the writer of the song that was inspired by words on a tombstone and is the first track on the box set Back to Mono?
# [wiki_search_engine] A: Phil Spector is the writer of the song that was inspired by words on a tombstone and is the first track on the box set Back to Mono.
# [wiki_search_engine] A: The first track on the box set Back to Mono is "Back to Mono (1958-1969)" by Phil Spector and Various Artists.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who are some notable former Soviet statesmen?
# [wiki_search_engine] Q: What forums or initiatives were started by Mikhail Gorbachev?
# [wiki_search_engine] Q: What forums or initiatives were started by Boris Yeltsin?
# [wiki_search_engine] Q: What forums or initiatives were started by Leonid Brezhnev?
# [wiki_search_engine] A: The All-Union Voluntary Society for the Struggle for Temperance was one of the forums or initiatives started during Gorbachev's leadership.
# [wiki_search_engine] A: Mikhail Gorbachev, Leonid Brezhnev, Nikita Khrushchev, Joseph Stalin, Yuri Andropov, Konstantin Chernenko.
# [wiki_search_engine] A: Boris Yeltsin initiated forums like the Congress of People's Deputies of Russia and the Supreme Soviet of the Russian Soviet Federative Socialist Republic. He also started initiatives such as the Russian presidential election in 1991 and the referendum on the future of the Soviet Union in 1991.
# [wiki_search_engine] A: Mikhail Gorbachev initiated the All-Union Voluntary Society for the Struggle for Temperance to promote sobriety and reduce alcohol consumption. He also allowed greater tolerance of religion, with initiatives such as broadcasting an Easter service on Soviet television for the first time and giving media attention to the millennium celebrations of the Russian Orthodox Church. Additionally, he announced that Soviet Jews wishing to migrate to Israel would be allowed to do so, which was previously prohibited.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is Ferocactus?
# [wiki_search_engine] Q: What is Silene?
# [wiki_search_engine] A: Ferocactus is a genus of large barrel-shaped cacti, mostly with large spines and small flowers. There are about 30 species included in the genus. They are found in the southwestern United States and northwestern Mexico.
# [wiki_search_engine] A: Silene is a genus of flowering plants in the family Caryophyllaceae, containing nearly 900 species. It is the largest genus in the family and is commonly known as campion and catchfly. Many Silene species are widely distributed, particularly in the northern hemisphere.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Which British first-generation jet-powered medium bomber was used in the South West Pacific theatre of World War II?
# [wiki_search_engine] Q: List of British jet-powered medium bombers used during World War II.
# [wiki_search_engine] Q: Details about the South West Pacific theatre of World War II and the aircraft used.
# [wiki_search_engine] A: English Electric Canberra
# [wiki_search_engine] A: The British jet-powered medium bombers used during World War II were the de Havilland Vampire and the Gloster Meteor.
# [wiki_search_engine] A: During World War II, the South West Pacific theatre was a significant area of conflict where Allied forces, primarily led by the United States, fought against Japanese forces. The region encompassed countries like Australia, New Guinea, the Philippines, and various Pacific islands. Aircraft played a crucial role in this theatre, with notable models including the Mitsubishi A6M Zero used by the Japanese, and Allied aircraft such as the Boeing B-17 Flying Fortress, the Grumman F6F Hellcat, and the Vought F4U Corsair. These aircraft were instrumental in conducting bombing raids, providing air support, and engaging in dogfights throughout the South West Pacific theatre.
# Generated 2 sub questions.
# [wiki_search_engine] Q: In which year did the Colorado Buffaloes have a record of 2-6 in conference play in the NCAA Division?
# [wiki_search_engine] Q: Which conference was the Colorado Buffaloes part of during their 14th season in the NCAA Division?
# [wiki_search_engine] A: In 2006, the Colorado Buffaloes had a record of 2-6 in conference play in the NCAA Division.
# [wiki_search_engine] A: The Colorado Buffaloes were part of the Pac-12 Conference during their 14th season in the NCAA Division.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What chain bought Euromarché in 1991?
# [wiki_search_engine] Q: How many hypermarkets did the chain that bought Euromarché operate at the end of 2016?
# [wiki_search_engine] A: Carrefour bought Euromarché in 1991.
# [wiki_search_engine] A: At the end of 2016, the chain that bought Euromarché operated 1,127 hypermarkets.
# Generated 3 sub questions.
# [wiki_search_engine] Q: What race track in the Midwest hosts a 500 mile race every May?
# [wiki_search_engine] Q: Which race track in the Midwest is known for hosting a major race in May?
# [wiki_search_engine] Q: Can you provide information on any 500 mile races held in the Midwest during May?
# [wiki_search_engine] A: Indianapolis Motor Speedway is known for hosting a major race in May.
# [wiki_search_engine] A: The Indianapolis Motor Speedway hosts a 500-mile race in late May known as the Indianapolis 500.
# [wiki_search_engine] A: The Indianapolis Motor Speedway in Speedway, Indiana hosts a 500 mile race every May, known as the Indianapolis 500.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who is referred to as the 'Prince of tenors'?
# [wiki_search_engine] Q: Which films did the 'Prince of tenors' star in?
# [wiki_search_engine] Q: Which of these films are based on operas by Giacomo Puccini?
# [wiki_search_engine] Q: In what city was the film based on an opera by Giacomo Puccini starring the 'Prince of tenors' set or filmed?
# [wiki_search_engine] A: Florence
# [wiki_search_engine] A: Enrico Caruso is referred to as the 'Prince of tenors'.
# [wiki_search_engine] A: The 'Prince of tenors' starred in the film "Epic Movie".
# [wiki_search_engine] A: None of the films mentioned in the context are based on operas by Giacomo Puccini.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who are the writers credited on Ellie Goulding's third studio album, Delirium?
# [wiki_search_engine] Q: What collaborations did Ellie Goulding have on her third studio album, Delirium?
# [wiki_search_engine] A: The writers credited on Ellie Goulding's third studio album, Delirium, are Ellie Goulding, Max Martin, Greg Kurstin, Ryan Tedder, and others.
# [wiki_search_engine] A: The collaborations Ellie Goulding had on her third studio album, Delirium, include a song with Scottish DJ Calvin Harris titled "Outside" and a collaboration with American electronic music trio Major Lazer featuring American-Jamaican singer Tarrus Riley on the track "Powerful."
# Generated 3 sub questions.
# [wiki_search_engine] Q: Which Australian city was founded in 1838?
# [wiki_search_engine] Q: Which Australian city contains a boarding school opened by a Prime Minister of Australia?
# [wiki_search_engine] Q: Which Australian city has a boarding school named after a school in London?
# [wiki_search_engine] A: Adelaide
# [wiki_search_engine] A: Adelaide
# [wiki_search_engine] A: Adelaide
# Generated 3 sub questions.
# [wiki_search_engine] Q: What is D1NZ?
# [wiki_search_engine] Q: What is the oversteering technique used in D1NZ?
# [wiki_search_engine] Q: What are the key features of the oversteering technique used in D1NZ?
# [wiki_search_engine] A: The oversteering technique used in D1NZ is drifting.
# [wiki_search_engine] A: The key features of the oversteering technique used in D1NZ include intentionally causing the rear slip angle to exceed the front slip angle, maintaining control while losing traction, and driving through a corner with the front wheels often pointing in the opposite direction to the turn. This technique is achieved through methods such as clutch kicking, weight transfer techniques like the Scandinavian flick, and utilizing a handbrake turn.
# [wiki_search_engine] A: D1NZ is a production car drifting series in New Zealand that organizes and regulates drifting events in the country. It consists of two national title competitions, the D1NZ Pro Championship and the D1NZ Pro-Sport Series. Competitors in D1NZ need to prove themselves in the Pro-Sport Series before progressing into the pro class, unless they have an equivalent international license. The series aims to promote and educate drifting in New Zealand in a regulated safe environment.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the birthdate of Keith Bostic?
# [wiki_search_engine] Q: What is the birthdate of Jerry Glanville?
# [wiki_search_engine] A: 1961
# [wiki_search_engine] A: The birthdate of Jerry Glanville is not provided in the context information.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What city is Kirton End located in?
# [wiki_search_engine] Q: What was the population of the city in which Kirton End is located according to the 2001 census?
# [wiki_search_engine] A: Kirton End is located in the city of Boston in Lincolnshire, England.
# [wiki_search_engine] A: The population of the city in which Kirton End is located according to the 2001 census was 55,750.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the classification of Cypress?
# [wiki_search_engine] Q: What is the classification of Ajuga?
# [wiki_search_engine] A: Cypress belongs to the Cupressaceae family.
# [wiki_search_engine] A: Ajuga is a genus of flowering plants in the Ajugeae tribe of the mint family Lamiaceae.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who were the members of the Charlotte Hornets during their 1992-93 season?
# [wiki_search_engine] Q: Who were the head coaches for the WNBA team Charlotte Sting?
# [wiki_search_engine] Q: Which former NBA player was a member of the Charlotte Hornets during their 1992-93 season and later became the head coach for the WNBA team Charlotte Sting?
# [wiki_search_engine] Q: What distinctions are held by former NBA players who have also been head coaches in the WNBA?
# [wiki_search_engine] A: Dave Cowens
# [wiki_search_engine] A: The head coaches for the WNBA team Charlotte Sting were Marynell Meadors, Anne Donovan, and Trudi Lacey.
# [wiki_search_engine] A: Former NBA players who have also been head coaches in the WNBA hold the distinction of having experience at the highest level of professional basketball as players and transitioning into coaching roles in the professional women's basketball league.
# [wiki_search_engine] A: Muggsy Bogues, Kendall Gill, Dell Curry, Johnny Newman, Kenny Gattison, David Wingate, Alonzo Mourning, Larry Johnson, Sidney Green, J.R. Reid, and Tom Hammonds were members of the Charlotte Hornets during their 1992-93 season.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Which films have a score composed by Jerry Goldsmith?
# [wiki_search_engine] Q: Who is the executive producer of the film [Film Name]?
# [wiki_search_engine] A: "Alien" is the film that has a score composed by Jerry Goldsmith.
# [wiki_search_engine] A: Peter Guber is the executive producer of the film "The Good Dinosaur".
# Generated 2 sub questions.
# [wiki_search_engine] Q: When was Emma Bull born?
# [wiki_search_engine] Q: When was Virginia Woolf born?
# [wiki_search_engine] A: Virginia Woolf was born on January 25, 1882.
# [wiki_search_engine] A: Emma Bull was born on December 13, 1954.
# Generated 3 sub questions.
# [wiki_search_engine] Q: What is the Roud Folk Song Index number for the nursery rhyme 'What Are Little Girls Made Of?'
# [wiki_search_engine] Q: What is the Roud Folk Song Index?
# [wiki_search_engine] Q: What is the history and origin of the nursery rhyme 'What Are Little Girls Made Of?'
# [wiki_search_engine] A: The Roud Folk Song Index number for the nursery rhyme 'What Are Little Girls Made Of?' is 821.
# [wiki_search_engine] A: The Roud Folk Song Index is a database of nearly 200,000 references to songs that have been collected from oral tradition in the English language.
# [wiki_search_engine] A: The nursery rhyme "What Are Little Girls Made Of?" is a variation of the original rhyme "What Are Little Boys Made Of?" dating back to the early 19th century. The authorship of the rhyme is uncertain, but it is often attributed to English poet Robert Southey (1774–1843). The rhyme describes little girls as being made of "sugar and spice and everything nice" or "all things nice." It is part of a larger work called "What Folks Are Made Of" or "What All the World Is Made Of," which includes stanzas describing what various groups of people are made of.
# Generated 5 sub questions.
# [wiki_search_engine] Q: Who is Scott Parkin?
# [wiki_search_engine] Q: What are Scott Parkin's criticisms of Exxonmobil?
# [wiki_search_engine] Q: Which other corporation has Scott Parkin criticized?
# [wiki_search_engine] Q: In how many countries does Exxonmobil operate?
# [wiki_search_engine] Q: In how many countries does the other corporation criticized by Scott Parkin operate?
# [wiki_search_engine] A: ExxonMobil
# [wiki_search_engine] A: Two countries
# [wiki_search_engine] A: ExxonMobil operates in approximately 70 countries worldwide.
# [wiki_search_engine] A: Scott Parkin has been a vocal critic of corporations such as ExxonMobil, among others.
# [wiki_search_engine] A: Scott Parkin is an anti-war, environmental, and global justice organizer who has been involved in various campaigns against corporations and initiatives that he believes are detrimental to society. He has also faced detention and removal by the Australian government due to being assessed as a threat to national security during a visit to Australia in 2005.
# Generated 4 sub questions.
# [wiki_search_engine] Q: What supernatural drama series aired on The WB network?
# [wiki_search_engine] Q: What television series did Rose McGowan star in?
# [wiki_search_engine] Q: What are the notable roles of Rose McGowan?
# [wiki_search_engine] Q: What is the connection between Rose McGowan and the movie Jawbreaker?
# [wiki_search_engine] A: Charmed
# [wiki_search_engine] A: Buffy the Vampire Slayer
# [wiki_search_engine] A: Rose McGowan starred in the movie Jawbreaker and based her performance on Gene Tierney's sociopathic character in Leave Her to Heaven.
# [wiki_search_engine] A: Rose McGowan's notable roles include her performance in the horror film "Scream" (1996), her role as Paige Matthews in the supernatural drama series "Charmed" (2001–2006), and her appearance in the double-feature film "Grindhouse" (2007) directed by Robert Rodriguez and Quentin Tarantino.
# Generated 3 sub questions.
# [wiki_search_engine] Q: What junior welterweight title did Vince Phillips hold?
# [wiki_search_engine] Q: Which organization recognized Vince Phillips' junior welterweight title?
# [wiki_search_engine] Q: What larger Hall of Fame is associated with the organization that recognized Vince Phillips' junior welterweight title?
# [wiki_search_engine] A: International Boxing Hall of Fame
# [wiki_search_engine] A: IBF junior welterweight title
# [wiki_search_engine] A: The Ring magazine
# Generated 3 sub questions.
# [wiki_search_engine] Q: What is the name of the singer who released the album 'Confessions'?
# [wiki_search_engine] Q: Which song was released as the lead single from the album 'Confessions'?
# [wiki_search_engine] Q: Which song was stuck behind the lead single from the album 'Confessions' for eight consecutive weeks?
# [wiki_search_engine] A: Tori Amos
# [wiki_search_engine] A: "Paperback Writer" was released as the lead single from the album 'Confessions'.
# [wiki_search_engine] A: "I Want to Hold Your Hand" was stuck behind the lead single from the album 'Confessions' for eight consecutive weeks.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who are the guest stars of the episode 'The Hard Easy'?
# [wiki_search_engine] Q: Who is the younger brother of each guest star of the episode 'The Hard Easy'?
# [wiki_search_engine] A: Brian Doyle-Murray appears as Prince Huge and Jonathan Katz as Mudscamp Elder.
# [wiki_search_engine] A: Edward is the younger brother of Brian Doyle-Murray, who guest-starred as Prince Huge in the episode 'The Hard Easy'.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the name of the league cup that Wigan Athletic F.C. competed in during the 2017–18 season for sponsorship reasons?
# [wiki_search_engine] Q: What were the sponsorship names of the league cup in the 2017–18 season?
# [wiki_search_engine] A: EFL Cup
# [wiki_search_engine] A: The sponsorship names of the league cup in the 2017–18 season were the Carabao Cup.
# Generated 4 sub questions.
# [wiki_search_engine] Q: What is Oranjegekte and how is it celebrated in the Netherlands?
# [wiki_search_engine] Q: What is Koningsdag and how is it celebrated in the Netherlands?
# [wiki_search_engine] Q: What color clothing is traditionally worn by people in the Netherlands during Oranjegekte?
# [wiki_search_engine] Q: What color clothing is traditionally worn by people in the Netherlands to celebrate Koningsdag?
# [wiki_search_engine] A: Orange
# [wiki_search_engine] A: Orange
# [wiki_search_engine] A: Koningsdag is a national holiday in the Netherlands celebrating the birthday of the King. It is celebrated with various activities such as parties, concerts, street markets (vrijmarkt), and festivals. People often dye their hair orange or wear orange clothing as a tribute to the House of Orange-Nassau, which rules over the Netherlands. Children participate in games like koekhappen and spijker poepen. The holiday is marked by a sense of community and belonging, with festivities taking place throughout the country, with Amsterdam being a popular destination for celebrations.
# [wiki_search_engine] A: Oranjegekte, also known as Orange craze or Orange fever, is a phenomenon in the Netherlands that occurs during major sporting events, Formula One Grands Prix, and during Koningsdag, an annual holiday celebrating the king's birthday. It is celebrated by wearing orange clothing such as T-shirts, caps, and scarfs; giving lavish attention to sports and sports fans in the media; and decorating cars, rooms, houses, shops, and even entire streets in orange, the traditional color of the Dutch royal family, the House of Orange-Nassau.
# Generated 3 sub questions.
# [wiki_search_engine] Q: What are the details of the 1996 loose adaptation of William Shakespeare's 'Romeo & Juliet' written by James Gunn?
# [wiki_search_engine] Q: Who wrote the 1996 loose adaptation of William Shakespeare's 'Romeo & Juliet'?
# [wiki_search_engine] Q: What are some notable adaptations of William Shakespeare's 'Romeo & Juliet'?
# [wiki_search_engine] A: Lloyd Kaufman and James Gunn wrote the 1996 loose adaptation of William Shakespeare's 'Romeo & Juliet'.
# [wiki_search_engine] A: The 1996 loose adaptation of William Shakespeare's 'Romeo & Juliet' written by James Gunn is titled "Tromeo and Juliet." It is an American independent transgressive romantic black comedy film directed by Lloyd Kaufman from a screenplay by Kaufman and James Gunn. The film includes extreme amounts of sexuality and violence characteristic of Troma, with a revised ending. The title "Tromeo and Juliet" is a blend of "Troma" and "Romeo and Juliet."
# [wiki_search_engine] A: Some notable adaptations of William Shakespeare's 'Romeo & Juliet' include the 1961 film "West Side Story," the 1996 film "Romeo + Juliet" directed by Baz Luhrmann, and the 2013 film "Warm Bodies" which is a zombie-themed adaptation of the classic play.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who is Robert Suettinger?
# [wiki_search_engine] Q: Who were the Governors of Arkansas?
# [wiki_search_engine] Q: Which former Governor of Arkansas had Robert Suettinger as the national intelligence officer?
# [wiki_search_engine] A: Bill Clinton
# [wiki_search_engine] A: Bill Clinton
# [wiki_search_engine] A: Robert Suettinger is an American international relations scholar who has held various positions in the U.S. government, including serving as the national intelligence officer for East Asia at the National Intelligence Council during the Clinton administration. He is currently a senior advisor at The Stimson Center and an advisor to the Inter-Parliamentary Alliance on China.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who is an American professional Hawaiian surfer born on 18 October 1992?
# [wiki_search_engine] Q: Which American professional Hawaiian surfer won the Rip Curl Pro Portugal?
# [wiki_search_engine] A: There is no information provided in the context about an American professional Hawaiian surfer born on 18 October 1992.
# [wiki_search_engine] A: The context information provided does not mention any American professional Hawaiian surfer who won the Rip Curl Pro Portugal.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who is the actress that plays Bobbi Bacha in Suburban Madness?
# [wiki_search_engine] Q: What is the full name of the actress who plays Bobbi Bacha in Suburban Madness?
# [wiki_search_engine] A: Marlene Dietrich
# [wiki_search_engine] A: The full name of the actress who plays Bobbi Bacha in Suburban Madness is Amber Laura Heard.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the nationality of social anthropologist Alfred Gell?
# [wiki_search_engine] Q: What is the nationality of social anthropologist Edmund Leach?
# [wiki_search_engine] A: British
# [wiki_search_engine] A: British
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who was the King who made the 1925 Birthday Honours?
# [wiki_search_engine] Q: In which year was King George V born?
# [wiki_search_engine] A: 1865
# [wiki_search_engine] A: George V
# Generated 2 sub questions.
# [wiki_search_engine] Q: In which county is East Lempster, New Hampshire located?
# [wiki_search_engine] Q: What is the county seat of the county where East Lempster, New Hampshire is located?
# [wiki_search_engine] A: Sullivan County
# [wiki_search_engine] A: The county seat of the county where East Lempster, New Hampshire is located is Newport.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the stage name of Robert C. Seger, born May 6, 1945?
# [wiki_search_engine] Q: What is the stage name of the rock singer who released the album 'Against the Wind'?
# [wiki_search_engine] A: Bob Seger
# [wiki_search_engine] A: Bob Seger
# Generated 5 sub questions.
# [wiki_search_engine] Q: What is the Rostker v. Goldberg case about?
# [wiki_search_engine] Q: What was the Supreme Court's decision in Rostker v. Goldberg?
# [wiki_search_engine] Q: What practice of filling armed forces vacancies was challenged in Rostker v. Goldberg?
# [wiki_search_engine] Q: Why was the practice of filling armed forces vacancies challenged in Rostker v. Goldberg?
# [wiki_search_engine] Q: What constitutional arguments were made in Rostker v. Goldberg?
# [wiki_search_engine] A: The practice of requiring only men to register for the draft was challenged in Rostker v. Goldberg.
# [wiki_search_engine] A: The Rostker v. Goldberg case is about the Supreme Court of the United States ruling that the practice of requiring only men to register for the draft was constitutional.
# [wiki_search_engine] A: The Supreme Court upheld the Act, holding that its gender distinction was not a violation of the equal protection component of the Due Process Clause of the Fifth Amendment.
# [wiki_search_engine] A: The practice of filling armed forces vacancies was challenged in Rostker v. Goldberg due to the gender distinction in the Military Selective Service Act of 1948, which required only men to register for the draft.
# [wiki_search_engine] A: The constitutional argument made in Rostker v. Goldberg was that the gender-based distinction in the Military Selective Service Act of 1948, which required only men to register for the draft, did not violate the equal protection component of the Due Process Clause of the Fifth Amendment.
# Generated 4 sub questions.
# [wiki_search_engine] Q: What is the book 'Their Lives: The Women Targeted by the Clinton Machine' about?
# [wiki_search_engine] Q: Who are the women mentioned in the book 'Their Lives: The Women Targeted by the Clinton Machine'?
# [wiki_search_engine] Q: Was there a former White House intern mentioned in the book 'Their Lives: The Women Targeted by the Clinton Machine'?
# [wiki_search_engine] Q: What is the name of the former White House intern mentioned in the book 'Their Lives: The Women Targeted by the Clinton Machine'?
# [wiki_search_engine] A: Monica Lewinsky
# [wiki_search_engine] A: Yes, Monica Lewinsky was mentioned in the book 'Their Lives: The Women Targeted by the Clinton Machine'.
# ...
# Generated 2 sub questions.
# [wiki_search_engine] Q: What railway runs through Summerseat?
# [wiki_search_engine] Q: What railway runs between Heywood and Rawtenstall?
# [wiki_search_engine] A: The East Lancashire Railway runs through Summerseat.
# [wiki_search_engine] A: The East Lancashire Railway runs between Heywood and Rawtenstall.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who was the English-born South Australian brewer whose brewery was amalgamated with W. K. Simms's West End Brewery?
# [wiki_search_engine] Q: When was the English-born South Australian brewer whose brewery was amalgamated with W. K. Simms's West End Brewery born?
# [wiki_search_engine] A: The English-born South Australian brewer whose brewery was amalgamated with W. K. Simms's West End Brewery was born in 1859.
# [wiki_search_engine] A: T. A. Nation was the English-born South Australian brewer whose brewery was amalgamated with W. K. Simms's West End Brewery.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who is Leopold Lummerstorfer?
# [wiki_search_engine] Q: Who is Valeria Sarmiento?
# [wiki_search_engine] Q: Is Leopold Lummerstorfer an author?
# [wiki_search_engine] Q: Is Valeria Sarmiento an author?
# [wiki_search_engine] A: No
# [wiki_search_engine] A: Yes.
# [wiki_search_engine] A: Leopold Lummerstorfer is an Austrian film director, author, and producer known for his work in the new Austrian cinema. He has directed various films and TV series, with a focus on social issues, and has received awards for his contributions to the film industry.
# [wiki_search_engine] A: Valeria Sarmiento is a film editor, director, and screenwriter known for her work in France, Portugal, and Chile. She has directed 20 feature films, documentaries, and television series, often focusing on melodrama, romantic drama, and costume drama with strong female characters.
# Generated 2 sub questions.
# [wiki_search_engine] Q: In which neighborhood is the William Ulmer Brewery located?
# [wiki_search_engine] Q: Which police precinct or department is responsible for the neighborhood where the William Ulmer Brewery is located?
# [wiki_search_engine] A: Bushwick
# [wiki_search_engine] A: The neighborhood where the William Ulmer Brewery is located falls under the jurisdiction of the New York City Police Department (NYPD).
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who is the main actor in Getting Married in Buffalo Jump?
# [wiki_search_engine] Q: Where was the main actor in Getting Married in Buffalo Jump born?
# [wiki_search_engine] A: The main actor in "Getting Married in Buffalo Jump" was born in Bree, Limburg, Belgium.
# [wiki_search_engine] A: There is no information provided in the context about the main actor in "Getting Married in Buffalo Jump."
# Generated 2 sub questions.
# [wiki_search_engine] Q: Who is Anna Lewandowska married to?
# [wiki_search_engine] Q: Which club does the footballer Robert Lewandowski play for?
# [wiki_search_engine] A: Barcelona
# [wiki_search_engine] A: Anna Lewandowska is married to the Polish footballer Robert Lewandowski.
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who is Tom Shearn?
# [wiki_search_engine] Q: Which teams did Tom Shearn play for during his career?
# [wiki_search_engine] Q: What is the history of the team that Tom Shearn was supposed to start for?
# [wiki_search_engine] Q: What are the former names of the team that Tom Shearn was supposed to start for?
# [wiki_search_engine] A: Tom Shearn did not play for the Beatles or the Kansas Jayhawks men's basketball team during his career.
# [wiki_search_engine] A: Tom Shearn is a former Major League Baseball pitcher who made his big league debut for the Cincinnati Reds after spending 11 years in the minor leagues.
# [wiki_search_engine] A: The former names of the team that Tom Shearn was supposed to start for are the Beatals, the Silver Beetles, and the Silver Beatles before finally becoming the Beatles.
# [wiki_search_engine] A: Tom Shearn was supposed to start for Altrincham, a team that was promoted to the National League in the 2013/14 season but was later relegated to the National League North two years later.
# Generated 2 sub questions.
# [wiki_search_engine] Q: In which state is the Nantahala National Forest located?
# [wiki_search_engine] Q: In which state is the Croatan National Forest located?
# [wiki_search_engine] A: North Carolina
# [wiki_search_engine] A: North Carolina
# Generated 4 sub questions.
# [wiki_search_engine] Q: Who is Zach Bogosian?
# [wiki_search_engine] Q: Who is Daron Malakian?
# [wiki_search_engine] Q: What is Zach Bogosian known for?
# [wiki_search_engine] Q: What is Daron Malakian known for?
# [wiki_search_engine] A: Zach Bogosian is known for his career as a professional ice hockey player in the NHL, particularly for his time with the Atlanta Thrashers/Winnipeg Jets franchise and the Buffalo Sabres.
# [wiki_search_engine] A: Daron Malakian is an Armenian-American musician known for his roles as the guitarist, songwriter, and second vocalist of the metal band System of a Down, as well as the lead vocalist, lead guitarist, multi-instrumentalist, and songwriter of Scars on Broadway.
# [wiki_search_engine] A: Daron Malakian is known for being an Armenian-American musician who is the guitarist, songwriter, and second vocalist of the metal band System of a Down, as well as the lead vocalist, lead guitarist, multi-instrumentalist, and songwriter of Scars on Broadway.
# [wiki_search_engine] A: Zach Bogosian is a professional ice hockey player who has played for teams like the Atlanta Thrashers, Winnipeg Jets, and Buffalo Sabres. He has had notable seasons where he set career highs in games played, goals, assists, and points. Bogosian was drafted third overall in the 2008 NHL Entry Draft and has been recognized for his skills as a defenseman in the league.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What was Sidney Lumet's career?
# [wiki_search_engine] Q: What was Albert Ward's career?
# [wiki_search_engine] A: Albert Ward's career involved being a British screenwriter and film director.
# [wiki_search_engine] A: Sidney Lumet started his career in theatre before transitioning to film. He became known for directing realistic and gritty New York dramas that focused on the working class, addressed social injustices, and often challenged authority. Throughout his career, Lumet directed a variety of films, including 12 Angry Men, Dog Day Afternoon, Network, The Verdict, Serpico, Murder on the Orient Express, and Before the Devil Knows You're Dead. He also worked on television, receiving accolades for his directing work on various series.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What is the nationality of Adolfo Bioy Casares?
# [wiki_search_engine] Q: What is the nationality of James Norman Hall?
# [wiki_search_engine] A: American
# [wiki_search_engine] A: Adolfo Bioy Casares was Argentine.
# Generated 4 sub questions.
# [wiki_search_engine] Q: What is the National Firearms Agreement?
# [wiki_search_engine] Q: What was the Port Arthur massacre?
# [wiki_search_engine] Q: How many people were killed in the Port Arthur massacre?
# [wiki_search_engine] Q: What was the response to the Port Arthur massacre?
# [wiki_search_engine] A: Several individuals lost their lives in the Port Arthur massacre.
# [wiki_search_engine] A: The Port Arthur massacre was a mass shooting that occurred on 28 April 1996 at Port Arthur, a tourist town in the Australian state of Tasmania. The perpetrator, Martin Bryant, killed 35 people and wounded 23 others, making it the deadliest massacre in modern Australian history.
# [wiki_search_engine] A: The National Firearms Agreement is an agreement concerning firearm control that was established by the Australasian Police Ministers' Council in 1996 in response to the Port Arthur massacre in Australia. It placed strict controls on semi-automatic and fully automatic weapons while allowing their use by licensed individuals for specific purposes other than personal protection. The agreement included provisions such as a temporary firearm buyback program, the creation of a national firearm registry, a 28-day waiting period for firearm sales, and tightened firearm licensing rules.
# [wiki_search_engine] A: The response to the Port Arthur massacre included the development of strict gun control laws in Australia. The Prime Minister of Australia, John Howard, led the initiative to implement the National Firearms Agreement, which restricted the private ownership of certain firearms and introduced uniform firearms licensing. This was done with bipartisan support from the Commonwealth, states, and territories. Additionally, there was a mandatory "buy-back" scheme for firearms, resulting in the surrender of 643,000 firearms at a cost of $350 million. The government also coordinated efforts to tighten controls on the legal ownership and use of certain firearms by recreational shooters.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Which Moscow theatre did Anna Aglatova make her first public appearance in 2005?
# [wiki_search_engine] Q: What is the biography of Anna Aglatova?
# [wiki_search_engine] A: Bolshoi Theatre
# [wiki_search_engine] A: Anna Aglatova is a Russian soprano singer born on March 4, 1982 in Kislovodsk. She joined the singing department of the Gnessin State Musical College in 2004 and has had a successful career in opera. She has won several awards and prizes, including the All-Russian Festival winner in 2008 and the Triumph prize recipient in the following year. Aglatova has performed in various roles at the Bolshoi Theatre and other opera houses, showcasing her talent as an operatic soprano.
# Generated 1 sub questions.
# [wiki_search_engine] Q: Which 2003 Indian drama features music by Ravi Khote?
# [wiki_search_engine] A: Kal Ho Naa Ho
# Generated 4 sub questions.
# [wiki_search_engine] Q: What is the 'Naked' film series?
# [wiki_search_engine] Q: What is the plot of 'Naked Weapon'?
# [wiki_search_engine] Q: What are the films in the 'Naked' series?
# [wiki_search_engine] Q: Which film precedes 'Naked Weapon' in the 'Naked' series?
# [wiki_search_engine] A: There is no mention of any films in the 'Naked' series in the provided context information.
# [wiki_search_engine] A: Naked Killer (1992) is the film that precedes 'Naked Weapon' in the 'Naked' series.
# [wiki_search_engine] A: The 'Naked' film series is a series of action films that follow the stories of young women who are trained as assassins by a woman named Madam M. The films depict the girls being sent on missions around the world, facing various challenges and betrayals as they navigate through dangerous situations. The series explores themes of revenge, loyalty, and the characters' quest for freedom and justice.
# [wiki_search_engine] A: The movie "Naked Weapon" revolves around three assassins who are trained by Madam M to become professional killers after being abducted and taken to an island. The girls, Charlene Ching, Katt, and Jing, survive the brutal training and are sent on missions around the world. The plot follows their journey as they navigate through dangerous assignments and face challenges orchestrated by Madam M and other adversaries.
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who is David Sinclair in the TV show 'Numb3rs'?
# [wiki_search_engine] Q: Which company produced the TV show 'Numb3rs'?
# [wiki_search_engine] Q: Where is the headquarters of the company that produced 'Numb3rs'?
# [wiki_search_engine] A: The company that produced the TV show 'Numb3rs' is The Weinstein Company.
# [wiki_search_engine] A: The headquarters of the company that produced 'Numb3rs' is located in Los Angeles, California.
# [wiki_search_engine] A: David Sinclair is a fictional character in the crime drama series Numb3rs. He is portrayed by Alimi Ballard and is introduced as a Special Agent in the FBI. Throughout the series, he becomes the usual partner of FBI Special Agent Colby Granger and later serves as the primary relief supervisor for Supervisor Don Eppes. Initially unpopular with critics, David Sinclair has since become a popular character on the show.
# Generated 2 sub questions.
# [wiki_search_engine] Q: Which casinos in Las Vegas are currently operated by MGM Resorts International?
# [wiki_search_engine] Q: Who is William G. Bennett and what casinos did he develop in Las Vegas?
# [wiki_search_engine] A: MGM Resorts International currently operates several casinos in Las Vegas, including the MGM Grand Las Vegas.
# [wiki_search_engine] A: William G. Bennett was an American gaming executive and real estate developer known for pioneering Las Vegas as a destination for middle-class tourists and families. He established Circus Circus Enterprises in 1974 and served as its chairman until 1994. Bennett developed the Excalibur and Luxor casinos in Las Vegas under Circus Circus. Additionally, he purchased the Sahara Hotel and Casino in Las Vegas in 1995 and operated it until his passing in 2002.
# Generated 2 sub questions.
# [wiki_search_engine] Q: What type of sport does Sergio Casal play?
# [wiki_search_engine] Q: What type of sport does Manuel Orantes play?
# [wiki_search_engine] A: Tennis
# [wiki_search_engine] A: Tennis
# Generated 3 sub questions.
# [wiki_search_engine] Q: Who is a former Australian rules football player who played with Port Adelaide in the South Australian National Football League?
# [wiki_search_engine] Q: Which video game company has a vice president who is a former Australian rules football player from Port Adelaide in the South Australian National Football League?
# [wiki_search_engine] Q: Where is the video game company, whose vice president is a former Australian rules football player from Port Adelaide in the South Australian National Football League, based?
# [wiki_search_engine] A: Nathan Bock
# [wiki_search_engine] A: The video game company, whose vice president is a former Australian rules football player from Port Adelaide in the South Australian National Football League, is based in Santa Monica, California.
# [wiki_search_engine] A: The video game company with a vice president who is a former Australian rules football player from Port Adelaide in the South Australian National Football League is Electronic Arts (EA).
# Generated 5 sub questions.
# [wiki_search_engine] Q: What is the history of Farda Amiga?
# [wiki_search_engine] Q: What are the notable achievements of Farda Amiga?
# [wiki_search_engine] Q: What races did Farda Amiga win?
# [wiki_search_engine] Q: What is the history of the Saratoga Race Course?
# [wiki_search_engine] Q: What notable races have been held at the Saratoga Race Course?
# [wiki_search_engine] A: Farda Amiga won the Kentucky Oaks and the Alabama Stakes during her racing career.
# [wiki_search_engine] A: The Saratoga Race Course has hosted notable races such as the Travers Stakes, the Whitney Handicap, and the Alabama Stakes.
# [wiki_search_engine] A: Farda Amiga won the Kentucky Oaks and the Alabama Stakes in her racing career. She was also named the American Champion Three-Year-Old Filly in the Eclipse Awards for 2002.
# [wiki_search_engine] A: The Saratoga Race Course is a historic horse racing track located in Saratoga Springs, New York. It is known for its rich history and tradition in American horse racing. The track opened in 1863 and has been a prominent venue for thoroughbred racing in the United States. Over the years, Saratoga Race Course has hosted many prestigious races, including the Travers Stakes and the Whitney Handicap. It is considered one of the oldest sporting venues in the country and continues to be a popular destination for horse racing enthusiasts.
# [wiki_search_engine] A: Farda Amiga, an American Thoroughbred racehorse and broodmare, was bred in Kentucky and owned by Brazilian horsemen. She showed promise racing on turf as a juvenile in 2001, winning on her debut and later winning the Kentucky Oaks and Alabama Stakes in 2002. She was retired after finishing second to Azeri in the Breeders' Cup Distaff. Farda Amiga was named American Champion Three-Year-Old Filly in 2002.

# %%
test_qa[0].keys()
# Out:
# dict_keys(['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context', 'ft_gen_ans'])

# %%
CORRECTNESS_INSTRUCTIONS = """
You are proficient in English and skilled at reading comprehension tasks. Your task is to evaluate a model-generated answer by comparing it to a provided ground truth answer. For each statement in the generated answer, classify it according to one of the following categories:

* Correct: The generated answer can be verified using the ground truth.
* Incorrect: The generated answer is either conflict or cannot be validated against the ground truth.
* NoAnswer: The generated answer indicates that the model does not know the answer or don't have the right context to answer the question.

Summarize your findings in the following JSON format:

{{
    "EvalResult": "Correct" / "Incorrect" / "NoAnswer" based on your analysis
}}
"""

USER_MESSAGE = """
Question:
{question}

Generated Answer:
{generated_answer}

Ground Truth:
{ground_truth}

Evaluation Result:
"""


def load_json_str(gen: str) -> dict:
    start = gen.index("{")
    end = gen.rindex("}") + 1

    # Extract the JSON string
    json_string = gen[start:end]
    return json.loads(json_string)


# gpt-4-1106-preview
async def call_chat_api(system_prompt, user_message, model="gpt-4o-mini", return_json=True) -> dict:
    """
    call the openai chat api with the given prompt.

    Args:
        system_prompt: str, system prompt
        user_message: str, user message
        model: str, the model name

    Return:

        response: dict, the response message from openai
    """
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_message},
    ]
    #     print(f"start a call with system prompt {system_prompt}")
    #     print(f"start a call with user message {user_message}")

    if return_json:
        response = await client.chat.completions.create(
            model=model, messages=messages, response_format={"type": "json_object"}
        )
    else:
        response = await client.chat.completions.create(
            model=model, messages=messages, response_format={"type": "text"}
        )
    return load_json_str(response.choices[0].message.content)


async def is_correct(record: dict) -> str:
    user_message = USER_MESSAGE.format(question=record["question"], generated_answer=record["ft_gen_ans"], ground_truth=record["answer"])
    result = await call_chat_api(
        system_prompt=CORRECTNESS_INSTRUCTIONS,
        user_message=user_message)
    # print(result)
    return result["EvalResult"]

# %%
def remove_punctuation(input_string: str):
    return input_string.translate(str.maketrans('', '', string.punctuation))


async def eval_record(record: dict) -> bool:
    # try to do a fuzzy match
    answer = remove_punctuation(record["ft_gen_ans"]).lower()
    gt = remove_punctuation(record["answer"]).lower()
    if answer in gt or gt in answer:
        return "Correct"
    else:
        return await is_correct(record)

# %%
import asyncio

semaphore = asyncio.Semaphore(2)


async def process_query(record, func):
    max_retry = 3
    async with semaphore:
        retry_count = 0
        while retry_count < max_retry:
            try:
                output = await func(record)
                break
            except Exception as e:
                retry_count += 1
                print(f"Retrying {retry_count} times due to exception: {e}")
                await asyncio.sleep(10)
                output = {}
        return output


async def execute(test_qa: Dataset, func):
    tasks = []
    for record in test_qa:
        task = asyncio.create_task(process_query(record, eval_record))
        tasks.append(task)
    return await asyncio.gather(*tasks, return_exceptions=True)

# %%
results = await execute(test_qa, eval_record)

# %%
from collections import Counter

# %%
eval_result = Counter(results)

# %%
eval_result
# Out:
# Counter({'Correct': 540, 'Incorrect': 430, 'NoAnswer': 30})

# %%
test_qa = test_qa.add_column("eval_result", results)

# %%
incorrect_qa = test_qa.filter(lambda example: example["eval_result"] == "Incorrect")
correct_qa = test_qa.filter(lambda example: example["eval_result"] == "Correct")
# Out:
# Filter:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
Counter(hotpot_qa["validation"]['level'])
# Out:
# Counter({'hard': 6260})

# %%
hotpot_qa["validation"]
# Out:
# Dataset({
#     features: ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context'],
#     num_rows: 6260
# })

# %% [markdown]
# ## As a comparison here are some latest SOTA results on HPQA
#
# https://contextual.ai/introducing-rag2/
